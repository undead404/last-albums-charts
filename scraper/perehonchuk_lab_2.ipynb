% %%
data = [4459 4462 4463];
data = data * (6.144 / 2 ^ 15)
% Out:
% data =4h
%
%    0.8361   0.8366   0.8368

% %%
data = load('data/dat16.txt');

% %%
size(data)
% Out:
% ans =04l
%
%    82487       2

% %%
t=data(:,1);
L=data(:,2);

% %%
V = L * (6.144 / 2 ^ 15);

% %%
mean_V = mean(V)
std_V = std(V)
snr_V = mean_V / std_V
% Out:
% mean_V = 0.8366
% std_V = 4.6601e-04
% snr_V = 1795.24l

% %%
plot(t, V)
xlabel('Voltage, V')
ylabel('time, s')
title('Perehonchuk – battery voltage')

% %%
plot(t, V)
xlabel('Voltage, V')
ylabel('time, s')
title('Perehonchuk – battery voltage')
xlim([20 20.1])

% %%
hist(V, 25)
xlabel('Voltage, V')
ylabel('frequency')
title('Perehonchuk – voltage distribution')
